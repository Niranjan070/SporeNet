# %% [markdown]
# # SporeNet Phase 0 Data Audit & Environment Notebook
# This notebook verifies synthetic weather telemetry, sample metadata, and temporal alignment feature vectors.

# %%
import pandas as pd
from pathlib import Path

repo_root = Path("..")
weather_df = pd.read_csv(repo_root / "data" / "synthetic" / "weather_stream.csv")
samples_df = pd.read_csv(repo_root / "data" / "synthetic" / "samples.csv")
aligned_df = pd.read_csv(repo_root / "data" / "processed" / "aligned_features.csv")

print(f"Weather rows: {len(weather_df):,}")
print(f"Samples count: {len(samples_df)}")
print(f"Aligned features count: {len(aligned_df)}")
aligned_df.head()
